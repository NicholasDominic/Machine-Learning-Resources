# %%
import pandas as pd
import seaborn as sb

# %% [markdown]
# ### Import Dataset

# %%
dataset = pd.read_csv("Data/Movie_collection_train.csv", header = 0)
dataset # print out in DataFrame format
# Out:
#      Collection  Marketing_expense  Production_expense  Multiplex_coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 395       26200           194.3350               91.20               0.307
# 396       25000           137.4410               91.20               0.307
# 397       17000           173.4404               91.20               0.307
# 398       10000           787.0360               91.20               0.307
# 399       12600           218.3310               91.20               0.307
#
# ...

# %% [markdown]
# ### [1] Data Exploration

# %%
# Extended Data Dictionary (EDD)
dataset.describe()
# Out:
#           Collection  Marketing_expense  Production_expense  \
# count     400.000000         400.000000          400.000000
# mean    48646.500000          55.017181           73.832700
# std     18308.499136         119.755634           13.023426
# min     10000.000000          20.126400           55.920000
# 25%     37800.000000          21.321950           63.250000
# 50%     45000.000000          23.214700           69.030000
# 75%     56500.000000          34.638300           82.840000
# max    100000.000000        1799.524000          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_Actor_Rating  \
# count          400.000000    400.000000    400.000000         400.000000
# mean             0.469881  35197.771537    137.581750           7.810275
# std              0.113920   4075.766926     28.990673           1.088694
# min              0.129000  19781.355000     76.400000           3.840000
# ...

# %% [markdown]
# ### [1.1] Data Cleaning: Missing/Null Values

# %%
dataset.isnull().any() # Check if there's any column which contains null values, marked/returned as TRUE
# Out:
# Collection             False
# Marketing_expense      False
# Production_expense     False
# Multiplex_coverage     False
# Budget                 False
# Movie_length           False
# Lead_Actor_Rating      False
# Lead_Actress_Rating    False
# Director_rating        False
# Producer_rating        False
# Critic_rating          False
# Trailer_views          False
# Time_taken              True
# Twitter_hastags        False
# Genre                  False
# Avg_age_actors         False
# MPAA_film_rating       False
# Num_multiplex          False
# 3D_available           False
# dtype: bool

# %%
col_has_null = dataset.columns[dataset.isnull().any()] # retrieve column name
dataset[col_has_null].isnull().sum() # retrieve number of rows which has null values

# Another way to show all columns which has NULL value(s)
# for i in col_has_null.tolist():
#     print("Total missing/null value(s) in {}: {}".format(i, dataset[i].isnull().sum()))
# Out:
# Time_taken    8
# dtype: int64

# %%
# Display rows which column has null value(s)
display_null_col = dataset[dataset.isnull().any(axis=1)]
display_null_col
# Out:
#      Collection  Marketing_expense  Production_expense  Multiplex_coverage  \
# 20        27200            45.0358               71.28               0.462
# 58        46600            23.0890               65.26               0.547
# 60        37400            22.9864               65.26               0.547
# 104       40200            22.7920               72.12               0.480
# 105       39000            22.6524               72.12               0.480
# 215       50000            23.9604               76.18               0.511
# 260       67600            30.8022               62.94               0.353
# 359       45200           105.2262               91.20               0.230
#
#         Budget  Movie_length  Lead_Actor_Rating  Lead_Actress_Rating  \
# 20   30941.350         171.6              8.035                8.205
# 58   34135.475         102.7              6.010                6.115
# 60   31891.255         139.7              6.335                6.420
# ...

# %%
sb.countplot(x = "MPAA_film_rating", data = dataset)

# %%
sb.scatterplot(x = "Marketing_expense", y = "Production_expense", hue = "Genre", data = dataset)

# %%
sb.scatterplot(x = "Producer_rating", y = "Producer_rating", hue = "Genre", data = dataset)

# %%
sb.scatterplot(x = "Director_rating", y = "Producer_rating", hue = "Genre", data = dataset)

# %%
sb.boxplot(x = "3D_available", y = "Multiplex_coverage", hue = "Genre", data = dataset)

# %%
sb.jointplot("Budget", "Multiplex_coverage", data=dataset, kind = "reg")

# %% [markdown]
# - Observation #1: Time_taken has 8 missing/null values
# - Observation #2: All MPAA_film_rating has same value == "PG"
# - Observation #3: Since Marketing_expense's std > mean, two outliers identified

# %%
dataset = pd.get_dummies(dataset) # Do one-hot encoding for nominal/categorical data

# %%
dataset = dataset.drop(['MPAA_film_rating_PG', '3D_available_NO'], axis=1)

# %%
dataset
# Out:
#      Collection  Marketing_expense  Production_expense  Multiplex_coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 395       26200           194.3350               91.20               0.307
# 396       25000           137.4410               91.20               0.307
# 397       17000           173.4404               91.20               0.307
# 398       10000           787.0360               91.20               0.307
# 399       12600           218.3310               91.20               0.307
#
# ...

# %%
dataset.corr()
# Out:
#                      Collection  Marketing_expense  Production_expense  \
# Collection             1.000000          -0.265558           -0.373947
# Marketing_expense     -0.265558           1.000000            0.351984
# Production_expense    -0.373947           0.351984            1.000000
# Multiplex_coverage     0.303971          -0.377417           -0.747325
# Budget                 0.754353          -0.167124           -0.403334
# Movie_length          -0.278718           0.290087            0.609577
# Lead_Actor_Rating     -0.110412           0.321276            0.668242
# Lead_Actress_Rating   -0.109230           0.323924            0.669666
# Director_rating       -0.105234           0.319799            0.668155
# Producer_rating       -0.112257           0.322379            0.672624
# Critic_rating          0.317850          -0.157808           -0.177960
# Trailer_views          0.678691          -0.366754           -0.537165
# ...

# %% [markdown]
# # Loading Data from CSV file

# %% [markdown]
# * The Pandas library in Python provides excellent, built-in support for time series data.
# * Pandas represents time series datasets as a **Series**.
# * A Series is a one-dimensional array with a time label for each row.
# * A Dataframe is a collection of series

# %%
import pandas as pd
import numpy as np

# %%
# Download csv file from resources and put it in working directory
dataframe = pd.read_csv('Data/daily-total-female-births-CA.csv', header=0)

# %% [markdown]
# #### First five records

# %%
dataframe.head()
# Out:
#        date  births
# 0  1/1/1959      35
# 1  1/2/1959      32
# 2  1/3/1959      30
# 3  1/4/1959      31
# 4  1/5/1959      44

# %% [markdown]
# #### Data Type

# %%
dataframe['date'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Loading data with parse_dates

# %%
df2 = pd.read_csv('Data/daily-total-female-births-CA.csv', header=0 , parse_dates=[0])

# %% [markdown]
# #### First five records

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %% [markdown]
# #### Data Type

# %%
df2['date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# #### Note
# dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
#
# df = pd.read_csv(.........,parse_dates=[0], date_parser=dateparse)
#
# https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior

# %% [markdown]
# ### Loading Data as a series

# %%
series = pd.read_csv('Data/daily-total-female-births-CA.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)

# %% [markdown]
# #### First 5 records

# %%
series.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %% [markdown]
# # Exploring Time Series Data

# %% [markdown]
# #### Size

# %%
series.shape
# Out:
# (365,)

# %%
df2.shape
# Out:
# (365, 2)

# %% [markdown]
# ### Querying by time

# %%
print(series['1959-01'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: births, dtype: int64

# %%
df2[(df2['date'] > '1959-01-01') & (df2['date'] <= '1959-01-21')]
# Out:
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34

# %% [markdown]
# ### Descriptive Statistics

# %%
series.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: births, dtype: float64

# %%
df2.describe()
# Out:
#            births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# * Date time features
# * Lag features
# * Window features
# * Expanding feature

# %% [markdown]
# ### Date time features

# %%
df2.head(5)
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
features = df2.copy()

# %%
features['year'] = df2['date'].dt.year

# %%
features['month'] = df2['date'].dt.month

# %%
features['day'] = df2['date'].dt.day

# %%
features.head(5)
# Out:
#         date  births  year  month  day
# 0 1959-01-01      35  1959      1    1
# 1 1959-01-02      32  1959      1    2
# 2 1959-01-03      30  1959      1    3
# 3 1959-01-04      31  1959      1    4
# 4 1959-01-05      44  1959      1    5

# %% [markdown]
# For more detail : https://pandas.pydata.org/pandas-docs/stable//reference/series.html#datetimelike-properties

# %% [markdown]
# ### Lag features

# %% [markdown]
# To create lag1 feature

# %%
features['lag2'] =  df2['births'].shift(2)

# %%
features['lag2'] =  df2['births'].shift(365)

# %%
features.head(7)
# Out:
#         date  births  year  month  day  lag2
# 0 1959-01-01      35  1959      1    1   NaN
# 1 1959-01-02      32  1959      1    2   NaN
# 2 1959-01-03      30  1959      1    3   NaN
# 3 1959-01-04      31  1959      1    4   NaN
# 4 1959-01-05      44  1959      1    5   NaN
# 5 1959-01-06      29  1959      1    6   NaN
# 6 1959-01-07      45  1959      1    7   NaN

# %% [markdown]
# For more detail : https://pandas.pydata.org/pandas-docs/stable//reference/api/pandas.Series.shift.html#pandas.Series.shift

# %% [markdown]
# ### Window features

# %%
features['Roll_mean'] = df2['births'].rolling(window = 2).mean()

# %%
features.head(5)
# Out:
#         date  births  year  month  day  lag2  Roll_mean
# 0 1959-01-01      35  1959      1    1   NaN        NaN
# 1 1959-01-02      32  1959      1    2   NaN       33.5
# 2 1959-01-03      30  1959      1    3   NaN       31.0
# 3 1959-01-04      31  1959      1    4   NaN       30.5
# 4 1959-01-05      44  1959      1    5   NaN       37.5

# %%
features['Roll_max'] = df2['births'].rolling(window = 3).max()

# %%
features.head(5)
# Out:
#         date  births  year  month  day  lag2  Roll_mean  Roll_max
# 0 1959-01-01      35  1959      1    1   NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2   NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3   NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4   NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5   NaN       37.5      44.0

# %% [markdown]
# For more detail : https://pandas.pydata.org/pandas-docs/stable//reference/api/pandas.Series.rolling.html#pandas.Series.rolling

# %% [markdown]
# ### Expanding features

# %%
features['Expand_max'] = df2['births'].expanding().max()

# %%
features.head(10)
# Out:
#         date  births  year  month  day  lag2  Roll_mean  Roll_max  Expand_max
# 0 1959-01-01      35  1959      1    1   NaN        NaN       NaN        35.0
# 1 1959-01-02      32  1959      1    2   NaN       33.5       NaN        35.0
# 2 1959-01-03      30  1959      1    3   NaN       31.0      35.0        35.0
# 3 1959-01-04      31  1959      1    4   NaN       30.5      32.0        35.0
# 4 1959-01-05      44  1959      1    5   NaN       37.5      44.0        44.0
# 5 1959-01-06      29  1959      1    6   NaN       36.5      44.0        44.0
# 6 1959-01-07      45  1959      1    7   NaN       37.0      45.0        45.0
# 7 1959-01-08      43  1959      1    8   NaN       44.0      45.0        45.0
# 8 1959-01-09      38  1959      1    9   NaN       40.5      45.0        45.0
# 9 1959-01-10      27  1959      1   10   NaN       32.5      43.0        45.0

# %% [markdown]
# For more detail : https://pandas.pydata.org/pandas-docs/stable//reference/api/pandas.Series.expanding.html#pandas.Series.expanding

# %% [markdown]
# # Time Series - Data Visualization

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
Dataviz_df = df2.copy()

# %%
Dataviz_df.head(10)
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44
# 5 1959-01-06      29
# 6 1959-01-07      45
# 7 1959-01-08      43
# 8 1959-01-09      38
# 9 1959-01-10      27

# %%
Dataviz_df['births'].plot()

# %%
Dataviz_df.index = Dataviz_df['date']

# %%
Dataviz_df['births'].plot()

# %% [markdown]
# ### Zooming In

# %%
Dataviz_df2 = Dataviz_df[(Dataviz_df['date'] > '1959-01-01') & (Dataviz_df['date'] <= '1959-01-10')].copy()

# %%
Dataviz_df2
# Out:
#                  date  births
# date
# 1959-01-02 1959-01-02      32
# 1959-01-03 1959-01-03      30
# 1959-01-04 1959-01-04      31
# 1959-01-05 1959-01-05      44
# 1959-01-06 1959-01-06      29
# 1959-01-07 1959-01-07      45
# 1959-01-08 1959-01-08      43
# 1959-01-09 1959-01-09      38
# 1959-01-10 1959-01-10      27

# %%
Dataviz_df2['births'].plot()

# %% [markdown]
# ### Trendline

# %%
import seaborn as sns

# %%
sns.regplot(x= df2.index.values, y=df2['births'])

# %%
sns.regplot(x= df2.index.values, y=df2['births'], order =2)

# %%
miles_df = pd.read_csv('Data/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_df['MilesMM'].plot()

# %%
sns.regplot(x= miles_df.index.values, y=miles_df['MilesMM'])

# %% [markdown]
# ### Removing Seasonality

# %%
miles_df['year'] = miles_df['Month'].dt.year

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year
# 0 1963-01-01     6827  1963
# 1 1963-02-01     6178  1963
# 2 1963-03-01     7084  1963
# 3 1963-04-01     8162  1963
# 4 1963-05-01     8462  1963

# %%
miles_df.groupby('year')['MilesMM'].mean()
# Out:
# year
# 1963     8300.250000
# 1964     8849.333333
# 1965     9619.250000
# 1966     9929.500000
# 1967    10542.916667
# 1968    10747.916667
# 1969    11972.000000
# 1970    13124.750000
# Name: MilesMM, dtype: float64

# %%
miles_df.groupby('year')['MilesMM'].mean().plot()

# %% [markdown]
# ### Creating Lag plots

# %%
miles_df['lag1'] =  miles_df['MilesMM'].shift(1)

# %%
miles_df.head()
# Out:
#        Month  MilesMM  year    lag1
# 0 1963-01-01     6827  1963     NaN
# 1 1963-02-01     6178  1963  6827.0
# 2 1963-03-01     7084  1963  6178.0
# 3 1963-04-01     8162  1963  7084.0
# 4 1963-05-01     8462  1963  8162.0

# %%
sns.scatterplot(x=miles_df['lag1'], y=miles_df['MilesMM'])

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(miles_df['MilesMM'])

# %% [markdown]
# ### Autocorrelation Plots

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(miles_df['MilesMM'])

# %% [markdown]
# ## Downsampling and Upsampling

# %%
miles_df = pd.read_csv('Data/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %% [markdown]
# ### Downsampling

# %%
quarterly_miles_df = miles_df.resample('Q', on='Month').mean()

# %%
quarterly_miles_df.head()
# Out:
#                  MilesMM
# Month
# 1963-03-31   6696.333333
# 1963-06-30   8756.000000
# 1963-09-30  10392.333333
# 1963-12-31   7356.333333
# 1964-03-31   7287.666667

# %%
yearly_total_miles_df = miles_df.resample('A', on='Month').sum()

# %%
yearly_total_miles_df.head()
# Out:
#             MilesMM
# Month
# 1963-12-31    99603
# 1964-12-31   106192
# 1965-12-31   115431
# 1966-12-31   119154
# 1967-12-31   126515

# %% [markdown]
# | Alias  | Description           |
# |--------|-----------------------|
# | B      | Business day          |
# | D      | Calendar day          |
# | W      | Weekly                |
# | M      | Month end             |
# | Q      | Quarter end           |
# | A      | Year end              |
# | BA     | Business year end     |
# | AS     | Year start            |
# | H      | Hourly frequency      |
# | T, min | Minutely frequency    |
# | S      | Secondly frequency    |
# | L, ms  | Millisecond frequency |
# | U, us  | Microsecond frequency |
# | N, ns  | Nanosecond frequency  |

# %% [markdown]
# ### Upsampling

# %%
upsampled_miles_df = miles_df.resample('D', on='Month').mean()

# %%
upsampled_miles_df.head(35)
# Out:
#             MilesMM
# Month
# 1963-01-01   6827.0
# 1963-01-02      NaN
# 1963-01-03      NaN
# 1963-01-04      NaN
# 1963-01-05      NaN
# 1963-01-06      NaN
# 1963-01-07      NaN
# 1963-01-08      NaN
# 1963-01-09      NaN
# 1963-01-10      NaN
# 1963-01-11      NaN
# 1963-01-12      NaN
# 1963-01-13      NaN
# 1963-01-14      NaN
# 1963-01-15      NaN
# 1963-01-16      NaN
# 1963-01-17      NaN
# 1963-01-18      NaN
# 1963-01-19      NaN
# 1963-01-20      NaN
# 1963-01-21      NaN
# 1963-01-22      NaN
# 1963-01-23      NaN
# 1963-01-24      NaN
# 1963-01-25      NaN
# 1963-01-26      NaN
# 1963-01-27      NaN
# 1963-01-28      NaN
# 1963-01-29      NaN
# 1963-01-30      NaN
# 1963-01-31      NaN
# 1963-02-01   6178.0
# 1963-02-02      NaN
# 1963-02-03      NaN
# 1963-02-04      NaN

# %%
interpolated_miles_df = upsampled_miles_df.interpolate(method='linear')

# %%
interpolated_miles_df.head(32)
# Out:
#                 MilesMM
# Month
# 1963-01-01  6827.000000
# 1963-01-02  6806.064516
# 1963-01-03  6785.129032
# 1963-01-04  6764.193548
# 1963-01-05  6743.258065
# 1963-01-06  6722.322581
# 1963-01-07  6701.387097
# 1963-01-08  6680.451613
# 1963-01-09  6659.516129
# 1963-01-10  6638.580645
# 1963-01-11  6617.645161
# 1963-01-12  6596.709677
# 1963-01-13  6575.774194
# 1963-01-14  6554.838710
# 1963-01-15  6533.903226
# 1963-01-16  6512.967742
# 1963-01-17  6492.032258
# 1963-01-18  6471.096774
# 1963-01-19  6450.161290
# 1963-01-20  6429.225806
# 1963-01-21  6408.290323
# 1963-01-22  6387.354839
# 1963-01-23  6366.419355
# 1963-01-24  6345.483871
# 1963-01-25  6324.548387
# 1963-01-26  6303.612903
# 1963-01-27  6282.677419
# 1963-01-28  6261.741935
# 1963-01-29  6240.806452
# 1963-01-30  6219.870968
# 1963-01-31  6198.935484
# 1963-02-01  6178.000000

# %%
interpolated_miles_df.head(35)
# Out:
#                 MilesMM
# Month
# 1963-01-01  6827.000000
# 1963-01-02  6806.064516
# 1963-01-03  6785.129032
# 1963-01-04  6764.193548
# 1963-01-05  6743.258065
# 1963-01-06  6722.322581
# 1963-01-07  6701.387097
# 1963-01-08  6680.451613
# 1963-01-09  6659.516129
# 1963-01-10  6638.580645
# 1963-01-11  6617.645161
# 1963-01-12  6596.709677
# 1963-01-13  6575.774194
# 1963-01-14  6554.838710
# 1963-01-15  6533.903226
# 1963-01-16  6512.967742
# 1963-01-17  6492.032258
# 1963-01-18  6471.096774
# 1963-01-19  6450.161290
# 1963-01-20  6429.225806
# 1963-01-21  6408.290323
# 1963-01-22  6387.354839
# 1963-01-23  6366.419355
# 1963-01-24  6345.483871
# 1963-01-25  6324.548387
# 1963-01-26  6303.612903
# 1963-01-27  6282.677419
# 1963-01-28  6261.741935
# 1963-01-29  6240.806452
# 1963-01-30  6219.870968
# 1963-01-31  6198.935484
# 1963-02-01  6178.000000
# 1963-02-02  6210.357143
# 1963-02-03  6242.714286
# 1963-02-04  6275.071429

# %%
interpolated_miles_df.plot()

# %%
interpolated_miles_df = upsampled_miles_df.interpolate(method='spline', order=2)

# %%
interpolated_miles_df.plot()

# %% [markdown]
# | Method  | Description                                               |
# |---------|-----------------------------------------------------------|
# | bfill   | Backward fill                                             |
# | count   | Count of values                                           |
# | ffill   | Forward fill                                              |
# | first   | First valid data value                                    |
# | last    | Last valid data value                                     |
# | max     | Maximum data value                                        |
# | mean    | Mean of values in time range                              |
# | median  | Median of values in time range                            |
# | min     | Minimum data value                                        |
# | nunique | Number of unique values                                   |
# | ohlc    | Opening value, highest value, lowest value, closing value |
# | pad     | Same as forward fill                                      |
# | std     | Standard deviation of values                              |
# | sum     | Sum of values                                             |
# | var     | Variance of values                                        |

# %% [markdown]
# ## Decomposing Time Series

# %% [markdown]
# **Additive Model**
#
# y(t) = Level + Trend + Seasonality + Noise
#
# **Multiplicative Model**
#
# y(t) = Level * Trend * Seasonality * Noise

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
miles_decomp_df = pd.read_csv('Data/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
miles_decomp_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_decomp_df.index = miles_decomp_df['Month']

# %%
seasonal_decompose(miles_decomp_df['MilesMM'], model='additive')

# %%
result2 = seasonal_decompose(miles_decomp_df['MilesMM'], model='multiplicative')

# %%
result2.plot()

# %% [markdown]
# ### Differencing

# %%
miles_df = pd.read_csv('Data/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_df['lag1'] =  miles_df['MilesMM'].shift(1)

# %%
miles_df['MilesMM_diff_1'] = miles_df['MilesMM'].diff(periods=1)

# %%
miles_df.head()
# Out:
#        Month  MilesMM    lag1  MilesMM_diff_1
# 0 1963-01-01     6827     NaN             NaN
# 1 1963-02-01     6178  6827.0          -649.0
# 2 1963-03-01     7084  6178.0           906.0
# 3 1963-04-01     8162  7084.0          1078.0
# 4 1963-05-01     8462  8162.0           300.0

# %%
miles_df.index = miles_df['Month'] 
result_a = seasonal_decompose(miles_df['MilesMM'], model='additive')
result_a.plot()

# %%
miles_df.index = miles_df['Month'] 
result_b = seasonal_decompose(miles_df.iloc[1:,3], model='additive')
result_b.plot()

# %%
miles_df['MilesMM'].plot()

# %%
miles_df['MilesMM_diff_1'].plot()

# %%
miles_df['MilesMM_diff_12'] = miles_df['MilesMM_diff_1'].diff(periods=12)

# %%
miles_df['MilesMM_diff_12'].plot()

# %%
result_c = seasonal_decompose(miles_df.iloc[13:,4], model='additive')
result_c.plot()

# %%
miles_df.head(50)
# Out:
#                 Month  MilesMM     lag1  MilesMM_diff_1  MilesMM_diff_12
# Month
# 1963-01-01 1963-01-01     6827      NaN             NaN              NaN
# 1963-02-01 1963-02-01     6178   6827.0          -649.0              NaN
# 1963-03-01 1963-03-01     7084   6178.0           906.0              NaN
# 1963-04-01 1963-04-01     8162   7084.0          1078.0              NaN
# 1963-05-01 1963-05-01     8462   8162.0           300.0              NaN
# 1963-06-01 1963-06-01     9644   8462.0          1182.0              NaN
# 1963-07-01 1963-07-01    10466   9644.0           822.0              NaN
# 1963-08-01 1963-08-01    10748  10466.0           282.0              NaN
# 1963-09-01 1963-09-01     9963  10748.0          -785.0              NaN
# 1963-10-01 1963-10-01     8194   9963.0         -1769.0              NaN
# 1963-11-01 1963-11-01     6848   8194.0         -1346.0              NaN
# 1963-12-01 1963-12-01     7027   6848.0           179.0              NaN
# 1964-01-01 1964-01-01     7269   7027.0           242.0              NaN
# 1964-02-01 1964-02-01     6775   7269.0          -494.0            155.0
# 1964-03-01 1964-03-01     7819   6775.0          1044.0            138.0
# 1964-04-01 1964-04-01     8371   7819.0           552.0           -526.0
# 1964-05-01 1964-05-01     9069   8371.0           698.0            398.0
# 1964-06-01 1964-06-01    10248   9069.0          1179.0             -3.0
# 1964-07-01 1964-07-01    11030  10248.0           782.0            -40.0
# 1964-08-01 1964-08-01    10882  11030.0          -148.0           -430.0
# 1964-09-01 1964-09-01    10333  10882.0          -549.0            236.0
# 1964-10-01 1964-10-01     9109  10333.0         -1224.0            545.0
# 1964-11-01 1964-11-01     7685   9109.0         -1424.0            -78.0
# 1964-12-01 1964-12-01     7602   7685.0           -83.0           -262.0
# 1965-01-01 1965-01-01     8350   7602.0           748.0            506.0
# 1965-02-01 1965-02-01     7829   8350.0          -521.0            -27.0
# 1965-03-01 1965-03-01     8829   7829.0          1000.0            -44.0
# 1965-04-01 1965-04-01     9948   8829.0          1119.0            567.0
# 1965-05-01 1965-05-01    10638   9948.0           690.0             -8.0
# 1965-06-01 1965-06-01    11253  10638.0           615.0           -564.0
# 1965-07-01 1965-07-01    11424  11253.0           171.0           -611.0
# 1965-08-01 1965-08-01    11391  11424.0           -33.0            115.0
# 1965-09-01 1965-09-01    10665  11391.0          -726.0           -177.0
# 1965-10-01 1965-10-01     9396  10665.0         -1269.0            -45.0
# 1965-11-01 1965-11-01     7775   9396.0         -1621.0           -197.0
# 1965-12-01 1965-12-01     7933   7775.0           158.0            241.0
# 1966-01-01 1966-01-01     8186   7933.0           253.0           -495.0
# 1966-02-01 1966-02-01     7444   8186.0          -742.0           -221.0
# 1966-03-01 1966-03-01     8484   7444.0          1040.0             40.0
# 1966-04-01 1966-04-01     9864   8484.0          1380.0            261.0
# 1966-05-01 1966-05-01    10252   9864.0           388.0           -302.0
# 1966-06-01 1966-06-01    12282  10252.0          2030.0           1415.0
# 1966-07-01 1966-07-01    11637  12282.0          -645.0           -816.0
# 1966-08-01 1966-08-01    11577  11637.0           -60.0            -27.0
# 1966-09-01 1966-09-01    12417  11577.0           840.0           1566.0
# 1966-10-01 1966-10-01     9637  12417.0         -2780.0          -1511.0
# 1966-11-01 1966-11-01     8094   9637.0         -1543.0             78.0
# 1966-12-01 1966-12-01     9280   8094.0          1186.0           1028.0
# 1967-01-01 1967-01-01     8334   9280.0          -946.0          -1199.0
# 1967-02-01 1967-02-01     7899   8334.0          -435.0            307.0

# %% [markdown]
# ## Test-Train Split

# %%
temp_df = pd.read_csv('Data/daily-min-temperatures.csv', header=0 , parse_dates=[0])

# %%
temp_df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-03  18.8
# 2 1981-01-04  14.6
# 3 1981-01-05  15.8
# 4 1981-01-06  15.8

# %%
temp_df.tail()
# Out:
#            Date  Temp
# 3646 1990-12-27  14.0
# 3647 1990-12-28  13.6
# 3648 1990-12-29  13.5
# 3649 1990-12-30  15.7
# 3650 1990-12-31  13.0

# %%
temp_df.shape
# Out:
# (3651, 2)

# %%
temp_df.shape[0]
# Out:
# 3651

# %%
train_size = int(temp_df.shape[0]*0.8)
train_size
# Out:
# 2920

# %%
train =  temp_df[0:train_size]

# %%
test =  temp_df[train_size:]

# %%
train.shape
# Out:
# (2920, 2)

# %%
test.shape
# Out:
# (731, 2)

# %% [markdown]
# ### Walk Forward Validation

# %% [markdown]
# ![walkforward2.png](attachment:walkforward2.png)

# %% [markdown]
# ### Persistence Model

# %%
df = pd.read_csv('Data/daily-min-temperatures.csv', header=0 , parse_dates=[0])

# %%
df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-03  18.8
# 2 1981-01-04  14.6
# 3 1981-01-05  15.8
# 4 1981-01-06  15.8

# %%
df['t'] =  df['Temp'].shift(1)

# %%
df.head()
# Out:
#         Date  Temp     t
# 0 1981-01-01  20.7   NaN
# 1 1981-01-03  18.8  20.7
# 2 1981-01-04  14.6  18.8
# 3 1981-01-05  15.8  14.6
# 4 1981-01-06  15.8  15.8

# %%
train, test = df[1:df.shape[0]-7], df[df.shape[0]-7:]

# %%
train.head()
# Out:
#         Date  Temp     t
# 1 1981-01-03  18.8  20.7
# 2 1981-01-04  14.6  18.8
# 3 1981-01-05  15.8  14.6
# 4 1981-01-06  15.8  15.8
# 5 1981-01-07  15.8  15.8

# %%
train_X, train_y = train['t'], train['Temp']
test_X, test_y = test['t'], test['Temp']

# %% [markdown]
# #### # walk-forward validation

# %%
predictions = test_X.copy()

# %%
print(predictions)
print(test_y)
# Out:
# 3644    10.0
# 3645    12.9
# 3646    14.6
# 3647    14.0
# 3648    13.6
# 3649    13.5
# 3650    15.7
# Name: t, dtype: float64
# 3644    12.9
# 3645    14.6
# 3646    14.0
# 3647    13.6
# 3648    13.5
# 3649    15.7
# 3650    13.0
# Name: Temp, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test_y, predictions)
mse
# Out:
# 3.4228571428571413

# %%
from matplotlib import pyplot

# %%
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')

# %% [markdown]
# ### Autoregression Model

# %%
df = pd.read_csv('Data/daily-min-temperatures.csv', header=0 , parse_dates=[0])

# %%
train, test = df.Temp[1:df.shape[0]-7], df.Temp[df.shape[0]-7:]

# %%
train.head()
# Out:
# 1    18.8
# 2    14.6
# 3    15.8
# 4    15.8
# 5    15.8
# Name: Temp, dtype: float64

# %%
from statsmodels.tsa.ar_model import AR

# %%
model = AR(train)
model_fit = model.fit()
# Out:
# c:\users\nicholas dominic\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)

# %% [markdown]
# #### No. of lag Variables

# %%
model_fit.k_ar
# Out:
# 29

# %% [markdown]
# #### Coef of lag variables

# %%
model_fit.params
# Out:
# const       0.557481
# L1.Temp     0.588396
# L2.Temp    -0.091091
# L3.Temp     0.048173
# L4.Temp     0.041540
# L5.Temp     0.037278
# L6.Temp     0.028380
# L7.Temp     0.043745
# L8.Temp     0.011474
# L9.Temp     0.037102
# L10.Temp   -0.000469
# L11.Temp    0.005874
# L12.Temp    0.020627
# L13.Temp    0.025724
# L14.Temp   -0.003641
# L15.Temp    0.027573
# L16.Temp    0.007430
# L17.Temp    0.011825
# L18.Temp    0.031487
# L19.Temp   -0.003137
# L20.Temp    0.018412
# L21.Temp    0.021824
# L22.Temp    0.009954
# L23.Temp   -0.019182
# L24.Temp    0.000984
# L25.Temp    0.014895
# L26.Temp    0.023938
# L27.Temp    0.004240
# L28.Temp    0.010274
# L29.Temp   -0.004261
# dtype: float64

# %%
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1)

# %%
predictions
# Out:
# 3644    11.838909
# 3645    13.037890
# 3646    13.521133
# 3647    13.219470
# 3648    13.089840
# 3649    13.143449
# 3650    13.204345
# dtype: float64

# %%
predictions.iloc[0]
# Out:
# 11.838908844090561

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test_y, predictions)
mse
# Out:
# 1.5265945164014318

# %%
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')

# %% [markdown]
# ### Walk Forward

# %%
df = pd.read_csv('Data/daily-min-temperatures.csv', header=0 , parse_dates=[0])

# %%
train, test = df.Temp[1:df.shape[0]-7], df.Temp[df.shape[0]-7:]

# %%
data = train
predict =[]
for t in test:
    model = AR(data)
    model_fit = model.fit()
    y = model_fit.predict(start=len(data), end=len(train)+len(test)-1)
    print(y.values[0])
    predict.append(y.values[0])
    data = np.append(data, t)
    data = pd.Series(data)
# Out:
# c:\users\nicholas dominic\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# 11.838908844090561
# 13.663662063985775
# 14.347590180474015
# 13.412760845824913
# 13.389335201601961
# 13.476747882795653
# 14.800365594699914

# %%
predict
# Out:
# [11.838908844090561,
#  13.663662063985775,
#  14.347590180474015,
#  13.412760845824913,
#  13.389335201601961,
#  13.476747882795653,
#  14.800365594699914]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test.values, predict)
mse
# Out:
# 1.4792762221177185

# %%
pyplot.plot(test.values)
pyplot.plot(predict, color='red')

# %% [markdown]
# ### Moving Average Model

# %%
df = pd.read_csv('Data/daily-min-temperatures.csv', header=0 , parse_dates=[0])

# %%
df['t'] =  df['Temp'].shift(1)

# %%
df['Resid'] = df['Temp'] - df['t']

# %%
df.head()
# Out:
#         Date  Temp     t  Resid
# 0 1981-01-01  20.7   NaN    NaN
# 1 1981-01-03  18.8  20.7   -1.9
# 2 1981-01-04  14.6  18.8   -4.2
# 3 1981-01-05  15.8  14.6    1.2
# 4 1981-01-06  15.8  15.8    0.0

# %%
train, test = df.Resid[1:df.shape[0]-7], df.Resid[df.shape[0]-7:]

# %%
train.head()
# Out:
# 1   -1.9
# 2   -4.2
# 3    1.2
# 4    0.0
# 5    0.0
# Name: Resid, dtype: float64

# %%
from statsmodels.tsa.ar_model import AR

# %%
model = AR(train)
model_fit = model.fit()
# Out:
# c:\users\nicholas dominic\appdata\local\programs\python\python37\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)

# %%
model_fit.k_ar
# Out:
# 29

# %%
model_fit.params
# Out:
# const       -0.006154
# L1.Resid    -0.407356
# L2.Resid    -0.496716
# L3.Resid    -0.446367
# L4.Resid    -0.402885
# L5.Resid    -0.363748
# L6.Resid    -0.333620
# L7.Resid    -0.288171
# L8.Resid    -0.275299
# L9.Resid    -0.236839
# L10.Resid   -0.235907
# L11.Resid   -0.228616
# L12.Resid   -0.206641
# L13.Resid   -0.179439
# L14.Resid   -0.181799
# L15.Resid   -0.152930
# L16.Resid   -0.144138
# L17.Resid   -0.131148
# L18.Resid   -0.098457
# L19.Resid   -0.100392
# L20.Resid   -0.080662
# L21.Resid   -0.057651
# L22.Resid   -0.046428
# L23.Resid   -0.064448
# L24.Resid   -0.062006
# L25.Resid   -0.045555
# L26.Resid   -0.019970
# L27.Resid   -0.014036
# L28.Resid   -0.001661
# L29.Resid   -0.005320
# dtype: float64

# %%
pred_resid = model_fit.predict(start=len(train), end=len(train)+len(test)-1)

# %%
pred_resid
# Out:
# 3644    1.970553
# 3645    1.284200
# 3646    0.503080
# 3647   -0.260302
# 3648   -0.095206
# 3649    0.072434
# 3650    0.087293
# dtype: float64

# %%
df.t[df.shape[0]-7:]
# Out:
# 3644    10.0
# 3645    12.9
# 3646    14.6
# 3647    14.0
# 3648    13.6
# 3649    13.5
# 3650    15.7
# Name: t, dtype: float64

# %%
predictions = df.t[df.shape[0]-7:] + pred_resid

# %%
predictions
# Out:
# 3644    11.970553
# 3645    14.184200
# 3646    15.103080
# 3647    13.739698
# 3648    13.504794
# 3649    13.572434
# 3650    15.787293
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test_y, predictions)
mse
# Out:
# 2.0812319957279515

# %%
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')

# %% [markdown]
# ## ARIMA Model

# %%
df = pd.read_csv('Data/shampoo.csv', header=0, parse_dates=[0])

# %%
df.head()
# Out:
#        Month  Sales
# 0 2020-01-01  266.0
# 1 2020-01-02  145.9
# 2 2020-01-03  183.1
# 3 2020-01-04  119.3
# 4 2020-01-05  180.3

# %%
df['Sales'].plot()

# %% [markdown]
# Trend is Polynomial.
# D =2

# %% [markdown]
# ### Autocorrelation Plot

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Sales'])

# %% [markdown]
#  q = 5

# %% [markdown]
# ### Partial Autocorrelation Graph

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(df['Sales'], lags=15)

# %% [markdown]
# p = 2

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(df['Sales'], order=(5,2,2))

# %%
# model_fit = model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                AR Model Results
# ==============================================================================
# Dep. Variable:                      R  -                  e                  s
# Model:                         AR(29)   Log Likelihood               -8293.931
# Method:                          cmle   S.D. of innovations              3.442
# Date:                Wed, 27 May 2020   AIC                              2.489
# Time:                        14:58:02   BIC                              2.542
# Sample:                             0   HQIC                             2.508
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0062      0.057     -0.107      0.915      -0.119       0.107
# L1.Resid      -0.4074      0.024    -17.006      0.000      -0.454      -0.360
# L2.Resid      -0.4967      0.026    -19.205      0.000      -0.547      -0.446
# L3.Resid      -0.4464      0.028    -15.681      0.000      -0.502      -0.391
# L4.Resid      -0.4029      0.030    -13.251      0.000      -0.462      -0.343
# L5.Resid      -0.3637      0.032    -11.410      0.000      -0.426      -0.301
# L6.Resid      -0.3336      0.033    -10.103      0.000      -0.398      -0.269
# L7.Resid      -0.2882      0.034     -8.491      0.000      -0.355      -0.222
# L8.Resid      -0.2753      0.035     -7.953      0.000      -0.343      -0.207
# L9.Resid      -0.2368      0.035     -6.726      0.000      -0.306      -0.168
# L10.Resid     -0.2359      0.036     -6.629      0.000      -0.306      -0.166
# L11.Resid     -0.2286      0.036     -6.359      0.000      -0.299      -0.158
# L12.Resid     -0.2066      0.036     -5.696      0.000      -0.278      -0.136
# L13.Resid     -0.1794      0.036     -4.923      0.000      -0.251      -0.108
# L14.Resid     -0.1818      0.037     -4.976      0.000      -0.253      -0.110
# L15.Resid     -0.1529      0.037     -4.176      0.000      -0.225      -0.081
# L16.Resid     -0.1441      0.037     -3.945      0.000      -0.216      -0.073
# L17.Resid     -0.1311      0.036     -3.597      0.000      -0.203      -0.060
# L18.Resid     -0.0985      0.036     -2.715      0.007      -0.170      -0.027
# L19.Resid     -0.1004      0.036     -2.795      0.005      -0.171      -0.030
# L20.Resid     -0.0807      0.036     -2.268      0.023      -0.150      -0.011
# L21.Resid     -0.0577      0.035     -1.639      0.101      -0.127       0.011
# L22.Resid     -0.0464      0.035     -1.342      0.180      -0.114       0.021
# L23.Resid     -0.0644      0.034     -1.900      0.057      -0.131       0.002
# L24.Resid     -0.0620      0.033     -1.878      0.060      -0.127       0.003
# L25.Resid     -0.0456      0.032     -1.429      0.153      -0.108       0.017
# L26.Resid     -0.0200      0.030     -0.657      0.511      -0.080       0.040
# L27.Resid     -0.0140      0.028     -0.493      0.622      -0.070       0.042
# L28.Resid     -0.0017      0.026     -0.064      0.949      -0.052       0.049
# L29.Resid     -0.0053      0.024     -0.222      0.824      -0.052       0.042
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.1496           -0.0000j            1.1496           -0.5000
# AR.2            -1.1172           -0.2826j            1.1524           -0.4606
# AR.3            -1.1172           +0.2826j            1.1524            0.4606
# AR.4            -1.0665           -0.5148j            1.1843           -0.4284
# AR.5            -1.0665           +0.5148j            1.1843            0.4284
# AR.6            -0.9089           -0.7290j            1.1651           -0.3924
# AR.7            -0.9089           +0.7290j            1.1651            0.3924
# AR.8            -0.7613           -0.9463j            1.2145           -0.3578
# AR.9            -0.7613           +0.9463j            1.2145            0.3578
# AR.10           -0.5132           -1.0377j            1.1576           -0.3231
# AR.11           -0.5132           +1.0377j            1.1576            0.3231
# AR.12            1.0751           -0.2626j            1.1067           -0.0381
# AR.13            1.0751           +0.2626j            1.1067            0.0381
# AR.14            1.0191           -0.4836j            1.1280           -0.0705
# AR.15            1.0191           +0.4836j            1.1280            0.0705
# AR.16            0.8613           -0.7018j            1.1110           -0.1088
# AR.17            0.8613           +0.7018j            1.1110            0.1088
# AR.18            0.6629           -0.8881j            1.1082           -0.1480
# AR.19            0.6629           +0.8881j            1.1082            0.1480
# AR.20            0.4215           -1.0387j            1.1210           -0.1887
# AR.21            0.4215           +1.0387j            1.1210            0.1887
# AR.22            0.1382           -1.1124j            1.1209           -0.2303
# AR.23            0.1382           +1.1124j            1.1209            0.2303
# AR.24           -0.1823           -1.1563j            1.1706           -0.2749
# AR.25           -0.1823           +1.1563j            1.1706            0.2749
# AR.26           -0.2782           -1.3534j            1.3817           -0.2823
# AR.27           -0.2782           +1.3534j            1.3817            0.2823
# AR.28            1.0683           -1.4872j            1.8311           -0.1509
# AR.29            1.0683           +1.4872j            1.8311            0.1509
# ------------------------------------------------------------------------------
# """

# %%
residuals = model_fit.resid

# %%
residuals.plot()

# %%
residuals.describe()
# Out:
# count    3614.000000
# mean       -0.000296
# std         3.442593
# min       -11.707723
# 25%        -2.183983
# 50%         0.102520
# 75%         2.161640
# max        14.886277
# dtype: float64

# %% [markdown]
# ### Variations
# * **ARIMA** - <br />
#     model = ARIMA(df['Sales'], order=(q,d,p)) <br />
# * **Autoregression** - <br />
#     model = ARIMA(df['Sales'], order=(p,d,0)) <br />
# * **Moving Avaerage Model** - <br />
#     model = ARIMA(df['Sales'], order=(0,d,q)) <br />

# %%
output = model_fit.forecast()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-7d2e0bd356e3> in <module>
# ----> 1 output = model_fit.forecast()
#
# c:\users\nicholas dominic\appdata\local\programs\python\python37\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      34             pass
#      35
# ---> 36         obj = getattr(results, attr)
#      37         data = results.model.data
#      38         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'ARResults' object has no attribute 'forecast'

# %%
output

# %%
model_fit.forecast(5)[0]

# %% [markdown]
# ### Walk Forward ARIMA

# %%
df = pd.read_csv('Data/shampoo.csv', header=0, parse_dates=[0])

# %%
df.head()

# %% [markdown]
# def parser(x):
# return datetime.strptime('190'+x, '%Y-%m')

# %%
train_size = int(df.shape[0]*0.7)

# %%
train, test = df.Sales[0:train_size], df.Sales[train_size:]

# %%
test.shape

# %%
data = train
predict =[]
for t in test:
    model = ARIMA(data, order=(5,1,0))
    model_fit = model.fit()
    y = model_fit.forecast()
    print(y[0][0])
    predict.append(y[0][0])
    data = np.append(data, t)
    data = pd.Series(data)

# %%
predict

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test.values, predict)
mse

# %% [markdown]
# ## SARIMA or Seasonal ARIMA
#
#
# SARIMA(p,d,q)(P,D,Q)m
#
# * p: Trend autoregression order.
# * d: Trend difference order.
# * q: Trend moving average order.
#
# **Seasonal Elements** -
# There are four seasonal elements that are not part of ARIMA that must be configured; they are:
#
# * P: Seasonal autoregressive order.
# * D: Seasonal difference order.
# * Q: Seasonal moving average order.
# * m: The number of time steps for a single seasonal period.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df = pd.read_csv('Data/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
df.head()

# %%
df.tail()

# %%
df.index = df['Month']

# %%
result_a = seasonal_decompose(df['MilesMM'], model='multiplicative')
result_a.plot()

# %%
model = SARIMAX(df['MilesMM'], order=(5,1,3), seasonal_order=(1,1,1,12))

# %%
model_fit = model.fit()

# %%
residuals = model_fit.resid

# %%
residuals.plot()

# %%
output = model_fit.forecast()

# %%
output

# %%
model_fit.forecast(12)

# %%
yhat = model_fit.predict()

# %%
yhat.head()

# %%
pyplot.plot(df['MilesMM'])
pyplot.plot(yhat, color='red')
